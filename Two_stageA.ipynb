# %%
#import libraries.
import numpy as np
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense
from tensorflow.python.keras.utils.data_utils import Sequence
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
import keras
from keras import regularizers
import sklearn
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error
from keras.initializers import glorot_normal
import sounddevice as sd
import tensorflow as tf
from mir_eval import separation 
from pystoi.stoi import stoi 
import h5py
from keras.callbacks import LearningRateScheduler
from keras.layers.normalization import BatchNormalization
from keras.layers import Activation
import math
from sklearn.utils import shuffle
# Out:
# Using TensorFlow backend.

# %%
#import libraries.
# import matplotlib.pyplot as plt
# from tabulate import tabulate
import time
import os
import librosa
from librosa.core import stft, istft
import time
import pickle
from keras import backend as K
from tensorflow.keras.models import load_model
# from keras.models import load_model

# %%
def reconstruct(wave,angle):
    recon1 = wave*np.cos(angle)+wave*np.sin(angle)*1j
#     recon = np.sqrt(np.power(10, wave))
#     recon1 = recon*np.cos(angle)+recon*np.sin(angle)*1j
    recon = librosa.core.istft((recon1.T), hop_length=160, win_length=400, window='hann')
    return recon

# %%
# # X, y = data_reading(0)
# X_dim= 1025
# y_dim = 2050
# estimator_A = Sequential()
# estimator_A.add(Dense(h_A[0], input_dim = X_dim, kernel_initializer='normal', activation='relu'))
# estimator_A.add(Dense(h_A[1], kernel_initializer='normal', activation='relu'))
# estimator_A.add(Dense(h_A[2], kernel_initializer='normal', activation='relu'))
# estimator_A.add(Dense(y_dim, kernel_initializer='normal', activation='relu'))
# # Compile model
# estimator_A.compile(loss='mean_squared_error', optimizer='adam')

# %%
data_series = str(4)

# %%
h5f = h5py.File('TIMIT/Organized/concatenated/mixed'  + data_series + '.hdf5','r')
X = h5f['mixed'  + data_series ][:]
h5f.close()

# %%
X.shape
# Out:
# (257, 279832)

# %%
h5f = h5py.File('TIMIT/Organized/concatenated/clean'  + data_series + '.hdf5','r')
y = h5f['clean'  + data_series ][:]
h5f.close()

# %%
# X_dim= 257
# y_dim = 514
# def DNN_A():
#     # create model
#     model = Sequential()
#     model.add(Dense(h_A[0], input_dim = X_dim, kernel_initializer='normal', activation='relu'))
#     model.add(Dense(h_A[1], kernel_initializer='normal', activation='relu'))
#     model.add(Dense(h_A[2], kernel_initializer='normal', activation='relu'))
#     model.add(Dense(y_dim, kernel_initializer='normal'))
#     # Compile model
#     model.compile(loss='mean_squared_error', optimizer='adam')
#     return model

# %%
# # seed = 1
# # np.random.seed(seed)
# print("^^^^^^^^^^^^^^^^^^^^^ Training with 5-fold on mixed0^^^^^^^^^^^^^^^^^^^^^")
# tic = time.time()
# estimator_A = KerasRegressor(build_fn=DNN_A, epochs=50, batch_size=100, verbose=1)
# # kfold = KFold(n_splits=2, random_state=seed)
# kfold = KFold(n_splits=5)
# results = cross_val_score(estimator_A, X.T, y.T, cv=kfold)
# print("Results: %.2f (%.2f) MSE" % (results.mean(), results.std()))
# toc_fold = time.time()

# print("^^^^^^^^^^^^^^^^^^^^^ Training on mixed0^^^^^^^^^^^^^^^^^^^^^")
# estimator_A.fit(X.T, y.T)
# # prediction = estimator_A.predict(X_test)

# toc_fit = time.time()
# Out:
# ^^^^^^^^^^^^^^^^^^^^^ Training with 5-fold on mixed0^^^^^^^^^^^^^^^^^^^^^
# Epoch 1/50
# 223864/223864 [==============================] - 11s 48us/sample - loss: 0.0154
# Epoch 2/50
# 223864/223864 [==============================] - 10s 47us/sample - loss: 0.0131
# Epoch 3/50
# 223864/223864 [==============================] - 11s 47us/sample - loss: 0.0123
# Epoch 4/50
# 223864/223864 [==============================] - 11s 48us/sample - loss: 0.0118
# Epoch 5/50
# 223864/223864 [==============================] - 11s 47us/sample - loss: 0.0115
# Epoch 6/50
# 223864/223864 [==============================] - 10s 47us/sample - loss: 0.0113
# Epoch 7/50
# 223864/223864 [==============================] - 11s 47us/sample - loss: 0.0110
# Epoch 8/50
# 223864/223864 [==============================] - 10s 47us/sample - loss: 0.0109
# Epoch 9/50
# 223864/223864 [==============================] - 10s 47us/sample - loss: 0.0107
# Epoch 10/50
# 223864/223864 [==============================] - 11s 47us/sample - loss: 0.0105
# Epoch 11/50
# 223864/223864 [==============================] - 11s 47us/sample - loss: 0.0104
# Epoch 12/50
# 223864/223864 [==============================] - 11s 47us/sample - loss: 0.0102
# Epoch 13/50
# 223864/223864 [==============================] - 10s 46us/sample - loss: 0.0101
# Epoch 14/50
# 223864/223864 [==============================] - 10s 46us/sample - loss: 0.0100
# Epoch 15/50
# 223864/223864 [==============================] - 10s 46us/sample - loss: 0.0099
# Epoch 16/50
# 223864/223864 [==============================] - 10s 46us/sample - loss: 0.0097
# Epoch 17/50
# 223864/223864 [==============================] - 10s 46us/sample - loss: 0.0097
# Epoch 18/50
# 223864/223864 [==============================] - 10s 46us/sample - loss: 0.0096
# Epoch 19/50
# 223864/223864 [==============================] - 10s 47us/sample - loss: 0.0095
# Epoch 20/50
# 223864/223864 [==============================] - 10s 47us/sample - loss: 0.0094
# Epoch 21/50
# 223864/223864 [==============================] - 10s 47us/sample - loss: 0.0093
# Epoch 22/50
# 223864/223864 [==============================] - 10s 46us/sample - loss: 0.0092
# Epoch 23/50
# 223864/223864 [==============================] - 10s 46us/sample - loss: 0.0092
# Epoch 24/50
# 223864/223864 [==============================] - 11s 47us/sample - loss: 0.0091
# Epoch 25/50
# 223864/223864 [==============================] - 11s 48us/sample - loss: 0.0090
# Epoch 26/50
# 223864/223864 [==============================] - 10s 46us/sample - loss: 0.0090
# Epoch 27/50
# 223864/223864 [==============================] - 10s 45us/sample - loss: 0.0089
# Epoch 28/50
# 223864/223864 [==============================] - 10s 43us/sample - loss: 0.0088
# Epoch 29/50
# 223864/223864 [==============================] - 9s 42us/sample - loss: 0.0088
# Epoch 30/50
# 223864/223864 [==============================] - 9s 41us/sample - loss: 0.0087
# Epoch 31/50
# 223864/223864 [==============================] - 10s 45us/sample - loss: 0.0087
# Epoch 32/50
# 223864/223864 [==============================] - 10s 45us/sample - loss: 0.0086
# Epoch 33/50
# 223864/223864 [==============================] - 11s 49us/sample - loss: 0.0086
# Epoch 34/50
# 223864/223864 [==============================] - 11s 49us/sample - loss: 0.0085
# Epoch 35/50
# 223864/223864 [==============================] - 10s 45us/sample - loss: 0.0085
# Epoch 36/50
# 223864/223864 [==============================] - 10s 45us/sample - loss: 0.0085
# Epoch 37/50
# 223864/223864 [==============================] - 10s 45us/sample - loss: 0.0084
# Epoch 38/50
# 223864/223864 [==============================] - 11s 47us/sample - loss: 0.0084
# Epoch 39/50
# 223864/223864 [==============================] - 10s 43us/sample - loss: 0.0083
# Epoch 40/50
# 223864/223864 [==============================] - 9s 42us/sample - loss: 0.0083
# Epoch 41/50
# 223864/223864 [==============================] - 9s 41us/sample - loss: 0.0082
# Epoch 42/50
# 223864/223864 [==============================] - 9s 41us/sample - loss: 0.0082
# Epoch 43/50
# 223864/223864 [==============================] - 9s 41us/sample - loss: 0.0082
# Epoch 44/50
# 223864/223864 [==============================] - 9s 41us/sample - loss: 0.0081
# Epoch 45/50
# 223864/223864 [==============================] - 9s 41us/sample - loss: 0.0081
# Epoch 46/50
# 223864/223864 [==============================] - 9s 41us/sample - loss: 0.0081
# Epoch 47/50
# 223864/223864 [==============================] - 10s 43us/sample - loss: 0.0081
# Epoch 48/50
# 223864/223864 [==============================] - 10s 45us/sample - loss: 0.0080
# Epoch 49/50
# 223864/223864 [==============================] - 9s 42us/sample - loss: 0.0080
# Epoch 50/50
# 223864/223864 [==============================] - 9s 42us/sample - loss: 0.0080
# 55967/55967 [==============================] - 1s 13us/sample - loss: 0.0109
# Epoch 1/50
# 223865/223865 [==============================] - 10s 45us/sample - loss: 0.0153
# Epoch 2/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0131
# Epoch 3/50
# 223865/223865 [==============================] - 9s 41us/sample - loss: 0.0122
# Epoch 4/50
# 223865/223865 [==============================] - 9s 41us/sample - loss: 0.0117
# Epoch 5/50
# 223865/223865 [==============================] - 9s 41us/sample - loss: 0.0114
# Epoch 6/50
# 223865/223865 [==============================] - 9s 41us/sample - loss: 0.0112
# Epoch 7/50
# 223865/223865 [==============================] - 9s 41us/sample - loss: 0.0110
# Epoch 8/50
# 223865/223865 [==============================] - 9s 41us/sample - loss: 0.0108
# Epoch 9/50
# 223865/223865 [==============================] - 9s 41us/sample - loss: 0.0106
# Epoch 10/50
# 223865/223865 [==============================] - 9s 41us/sample - loss: 0.0104
# Epoch 11/50
# 223865/223865 [==============================] - 9s 41us/sample - loss: 0.0103
# Epoch 12/50
# 223865/223865 [==============================] - 9s 41us/sample - loss: 0.0102
# Epoch 13/50
# 223865/223865 [==============================] - 9s 41us/sample - loss: 0.0100
# Epoch 14/50
# 223865/223865 [==============================] - 9s 41us/sample - loss: 0.0099
# Epoch 15/50
# 223865/223865 [==============================] - 9s 41us/sample - loss: 0.0098
# Epoch 16/50
# 223865/223865 [==============================] - 9s 41us/sample - loss: 0.0097
# Epoch 17/50
# 223865/223865 [==============================] - 9s 41us/sample - loss: 0.0096
# Epoch 18/50
# 223865/223865 [==============================] - 9s 41us/sample - loss: 0.0095
# Epoch 19/50
# 223865/223865 [==============================] - 9s 41us/sample - loss: 0.0094
# Epoch 20/50
# 223865/223865 [==============================] - 9s 41us/sample - loss: 0.0093
# Epoch 21/50
# 223865/223865 [==============================] - 9s 41us/sample - loss: 0.0092
# Epoch 22/50
# 223865/223865 [==============================] - 9s 41us/sample - loss: 0.0092
# Epoch 23/50
# 223865/223865 [==============================] - 9s 41us/sample - loss: 0.0091
# Epoch 24/50
# 223865/223865 [==============================] - 9s 41us/sample - loss: 0.0090
# Epoch 25/50
# 223865/223865 [==============================] - 9s 41us/sample - loss: 0.0089
# Epoch 26/50
# 223865/223865 [==============================] - 9s 41us/sample - loss: 0.0089
# Epoch 27/50
# 223865/223865 [==============================] - 9s 41us/sample - loss: 0.0088
# Epoch 28/50
# 223865/223865 [==============================] - 9s 41us/sample - loss: 0.0088
# Epoch 29/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0087
# Epoch 30/50
# 223865/223865 [==============================] - 9s 41us/sample - loss: 0.0087
# Epoch 31/50
# 223865/223865 [==============================] - 10s 44us/sample - loss: 0.0086
# Epoch 32/50
# 223865/223865 [==============================] - 10s 43us/sample - loss: 0.0086
# Epoch 33/50
# 223865/223865 [==============================] - 9s 41us/sample - loss: 0.0085
# Epoch 34/50
# 223865/223865 [==============================] - 9s 41us/sample - loss: 0.0085
# Epoch 35/50
# 223865/223865 [==============================] - 9s 41us/sample - loss: 0.0083
# Epoch 36/50
# 223865/223865 [==============================] - 9s 41us/sample - loss: 0.0084
# Epoch 37/50
# 223865/223865 [==============================] - 9s 41us/sample - loss: 0.0083
# Epoch 38/50
# 223865/223865 [==============================] - 9s 41us/sample - loss: 0.0082
# Epoch 39/50
# 223865/223865 [==============================] - 9s 41us/sample - loss: 0.0083
# Epoch 40/50
# 223865/223865 [==============================] - 9s 41us/sample - loss: 0.0082
# Epoch 41/50
# 223865/223865 [==============================] - 10s 46us/sample - loss: 0.0082
# Epoch 42/50
# 223865/223865 [==============================] - 10s 46us/sample - loss: 0.0081
# Epoch 43/50
# 223865/223865 [==============================] - 10s 42us/sample - loss: 0.0080
# Epoch 44/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0081
# Epoch 45/50
# 223865/223865 [==============================] - 10s 46us/sample - loss: 0.0080
# Epoch 46/50
# 223865/223865 [==============================] - 11s 48us/sample - loss: 0.0080
# Epoch 47/50
# 223865/223865 [==============================] - 10s 43us/sample - loss: 0.0080
# Epoch 48/50
# 223865/223865 [==============================] - 10s 46us/sample - loss: 0.0079
# Epoch 49/50
# 223865/223865 [==============================] - 10s 46us/sample - loss: 0.0079
# Epoch 50/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0078
# 55966/55966 [==============================] - 1s 13us/sample - loss: 0.0111
# Epoch 1/50
# 223865/223865 [==============================] - 10s 43us/sample - loss: 0.0153
# Epoch 2/50
# 223865/223865 [==============================] - 9s 41us/sample - loss: 0.0130
# Epoch 3/50
# 223865/223865 [==============================] - 9s 41us/sample - loss: 0.0122
# Epoch 4/50
# 223865/223865 [==============================] - 9s 41us/sample - loss: 0.0117
# Epoch 5/50
# 223865/223865 [==============================] - 9s 41us/sample - loss: 0.0114
# Epoch 6/50
# 223865/223865 [==============================] - 10s 46us/sample - loss: 0.
50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0089
# Epoch 27/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0089
# Epoch 28/50
# 223865/223865 [==============================] - 10s 43us/sample - loss: 0.0088
# Epoch 29/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0087
# Epoch 30/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0087
# Epoch 31/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0086
# Epoch 32/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0085
# Epoch 33/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0085
# Epoch 34/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0085
# Epoch 35/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0084
# Epoch 36/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0084
# Epoch 37/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0083
# Epoch 38/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0083
# Epoch 39/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0083
# Epoch 40/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0083
# Epoch 41/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0082
# Epoch 42/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0081
# Epoch 43/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0082
# Epoch 44/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0081
# Epoch 45/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0081
# Epoch 46/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0081
# Epoch 47/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0080
# Epoch 48/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0080
# Epoch 49/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0080
# Epoch 50/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0079
# 55966/55966 [==============================] - 1s 15us/sample - loss: 0.0108
# Epoch 1/50
# 223865/223865 [==============================] - 10s 44us/sample - loss: 0.0154
# Epoch 2/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0132
# Epoch 3/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0123
# Epoch 4/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0118
# Epoch 5/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0115
# Epoch 6/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0112
# Epoch 7/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0110
# Epoch 8/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0108
# Epoch 9/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0106
# Epoch 10/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0105
# Epoch 11/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0103
# Epoch 12/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0102
# Epoch 13/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0100
# Epoch 14/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0099
# Epoch 15/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0098
# Epoch 16/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0097
# Epoch 17/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0096
# Epoch 18/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0095
# Epoch 19/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0094
# Epoch 20/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0093
# Epoch 21/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0093
# Epoch 22/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0092
# Epoch 23/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0091
# Epoch 24/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0091
# Epoch 25/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0090
# Epoch 26/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0089
# Epoch 27/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0089
# Epoch 28/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0088
# Epoch 29/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0087
# Epoch 30/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0087
# Epoch 31/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0087
# Epoch 32/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0086
# Epoch 33/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0085
# Epoch 34/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0085
# Epoch 35/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0085
# Epoch 36/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0084
# Epoch 37/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0084
# Epoch 38/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0084
# Epoch 39/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0083
# Epoch 40/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0083
# Epoch 41/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0082
# Epoch 42/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0082
# Epoch 43/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0082
# Epoch 44/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0081
# Epoch 45/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0081
# Epoch 46/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0081
# Epoch 47/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0081
# Epoch 48/50
# 223865/223865 [==============================] - 9s 42us/sample - loss: 0.0080
# Epoch 49/50
# 223865/223865 [==============================] - 10s 43us/sample - loss: 0.0080
# Epoch 50/50
# 223865/223865 [==============================] - 10s 44us/sample - loss: 0.0080
# 55966/55966 [==============================] - 1s 17us/sample - loss: 0.0105
# Results: -0.01 (0.00) MSE
# ^^^^^^^^^^^^^^^^^^^^^ Training on mixed0^^^^^^^^^^^^^^^^^^^^^
# Epoch 1/50
# 279831/279831 [==============================] - 20s 70us/sample - loss: 0.0150
# Epoch 2/50
# 279831/279831 [==============================] - 18s 66us/sample - loss: 0.0127
# Epoch 3/50
# 279831/279831 [==============================] - 18s 64us/sample - loss: 0.0120
# Epoch 4/50
# 279831/279831 [==============================] - 21s 74us/sample - loss: 0.0116
# Epoch 5/50
# 279831/279831 [==============================] - 21s 76us/sample - loss: 0.0113
# Epoch 6/50
# 279831/279831 [==============================] - 20s 73us/sample - loss: 0.0111
# Epoch 7/50
# 279831/279831 [==============================] - 21s 74us/sample - loss: 0.0109
# Epoch 8/50
# 279831/279831 [==============================] - 21s 76us/sample - loss: 0.0107
# Epoch 9/50
# 279831/279831 [==============================] - 22s 77us/sample - loss: 0.0105
# Epoch 10/50
# 279831/279831 [==============================] - 20s 70us/sample - loss: 0.0104
# Epoch 11/50
# 279831/279831 [==============================] - 20s 71us/sample - loss: 0.0102
# Epoch 12/50
# 279831/279831 [==============================] - 20s 71us/sample - loss: 0.0101
# Epoch 13/50
# 279831/279831 [==============================] - 20s 70us/sample - loss: 0.0099
# Epoch 14/50
# 279831/279831 [==============================] - 20s 70us/sample - loss: 0.0099
# Epoch 15/50
# 279831/279831 [==============================] - 20s 73us/sample - loss: 0.0097
# Epoch 16/50
# 279831/279831 [==============================] - 20s 70us/sample - loss: 0.0097
# Epoch 17/50
# 279831/279831 [==============================] - 19s 67us/sample - loss: 0.0096
# Epoch 18/50
# 279831/279831 [==============================] - 19s 68us/sample - loss: 0.0095
# Epoch 19/50
# 279831/279831 [==============================] - 18s 65us/sample - loss: 0.0094
# Epoch 20/50
# 279831/279831 [==============================] - 19s 67us/sample - loss: 0.0094
# Epoch 21/50
# 279831/279831 [==============================] - 20s 70us/sample - loss: 0.0093
# Epoch 22/50
# 279831/279831 [==============================] - 20s 73us/sample - loss: 0.0092
# Epoch 23/50
# 279831/279831 [==============================] - 18s 64us/sample - loss: 0.0092
# Epoch 24/50
# 279831/279831 [==============================] - 18s 64us/sample - loss: 0.0091
# Epoch 25/50
# 279831/279831 [==============================] - 18s 64us/sample - loss: 0.0090
# Epoch 26/50
# 279831/279831 [==============================] - 18s 64us/sample - loss: 0.0090
# Epoch 27/50
# 279831/279831 [==============================] - 18s 64us/sample - loss: 0.0089
# Epoch 28/50
# 279831/279831 [==============================] - 18s 64us/sample - loss: 0.0088
# Epoch 29/50
# 279831/279831 [==============================] - 18s 64us/sample - loss: 0.0088
# Epoch 30/50
# 279831/279831 [==============================] - 18s 64us/sample - loss: 0.0088
# Epoch 31/50
# 279831/279831 [==============================] - 18s 64us/sample - loss: 0.0087
# Epoch 32/50
# 279831/279831 [==============================] - 19s 68us/sample - loss: 0.0086
# Epoch 33/50
# 279831/279831 [==============================] - 19s 70us/sample - loss: 0.0086
# Epoch 34/50
# 279831/279831 [==============================] - 20s 71us/sample - loss: 0.0086
# Epoch 35/50
# 279831/279831 [==============================] - 20s 71us/sample - loss: 0.0085
# Epoch 36/50
# 279831/279831 [==============================] - 20s 71us/sample - loss: 0.0085
# Epoch 37/50
# 279831/279831 [==============================] - 20s 72us/sample - loss: 0.0085
# Epoch 38/50
# 279831/279831 [==============================] - 19s 69us/sample - loss: 0.0084
# Epoch 39/50
# 279831/279831 [==============================] - 24s 85us/sample - loss: 0.0084
# Epoch 40/50
# 279831/279831 [==============================] - 22s 77us/sample - loss: 0.0083
# Epoch 41/50
# 279831/279831 [==============================] - 21s 74us/sample - loss: 0.0083
# Epoch 42/50
# 279831/279831 [==============================] - 22s 79us/sample - loss: 0.0083
# Epoch 43/50
# 279831/279831 [==============================] - 20s 70us/sample - loss: 0.0082
# Epoch 44/50
# 279831/279831 [==============================] - 18s 64us/sample - loss: 0.0082
# Epoch 45/50
# 279831/279831 [==============================] - 18s 64us/sample - loss: 0.0082
# Epoch 46/50
# 279831/279831 [==============================] - 20s 71us/sample - loss: 0.0082
# Epoch 47/50
# 279831/279831 [==============================] - 20s 70us/sample - loss: 0.0081
# Epoch 48/50
# 279831/279831 [==============================] - 20s 72us/sample - loss: 0.0081
# Epoch 49/50
# 279831/279831 [==============================] - 20s 70us/sample - loss: 0.0081
# Epoch 50/50
# 279831/279831 [==============================] - 20s 71us/sample - loss: 0.0081

# %%
def da(load_size, data_len):
    global I
    h5f1 = h5py.File('TIMIT/Organized/concatenated/mixed'  + data_series + '.hdf5','r')
    h5f2 = h5py.File('TIMIT/Organized/concatenated/clean'  + data_series + '.hdf5','r')
    indx = np.arange(0, data_len, load_size)
    indx = shuffle(indx, random_state=0)
    print(indx)
    while True:             #this line is just because keras needs infinite generators
        for I in indx: 
            if data_len-I<load_size:
                Data1 = h5f1['mixed' + data_series][:,I:].T
                Data2 = h5f2['clean' + data_series][:,I:].T
            else:
                Data1 = h5f1['mixed' + data_series][:,I:I+load_size].T
                Data2 = h5f2['clean' + data_series][:,I:I+load_size].T
            Data1 = sklearn.preprocessing.normalize(Data1, norm='l2', axis=1, copy=True, return_norm=False)
#             Data2 = sklearn.preprocessing.normalize(Data2, norm='l2', axis=1, copy=True, return_norm=False)
            a = Data2[:,0:257]
            b = Data2[:,257:]
#             print(a)
#             print('******************')
#             print(b)
#             print('******************')
            Mask = a/Data1
#             print(Data2[:,0:257])
            Mask = np.concatenate((Mask,b/Data1), axis = 1)
            Mask = sklearn.preprocessing.normalize(Mask, norm='l2', axis=1, copy=True, return_norm=False)
            yield(Data1, Mask)

# %%
a , b = next(da(batch_size, ftr_shape[1]))
# Out:
# [139000  19600  25300 ... 165300 260700 273200]

# %%
b.shape
# Out:
# (100, 514)

# %%
aa = sklearn.preprocessing.normalize(a, norm='l2', axis=1, copy=True, return_norm=False)

# %%
np.max(aa)
# Out:
# 0.65326005

# %%
# h_A = [300,400, 600]
h_A = [257,257, 257]

# %%
# X, y = data_reading(0)
X_dim= 257
y_dim = 514
estimator_A = Sequential()
estimator_A.add(Dense(h_A[0], input_dim = X_dim, kernel_initializer=glorot_normal(seed=None)))
estimator_A.add(BatchNormalization())
estimator_A.add(Activation('sigmoid'))
estimator_A.add(Dense(h_A[1], kernel_initializer=glorot_normal(seed=None)))
estimator_A.add(BatchNormalization())
estimator_A.add(Activation('sigmoid'))
estimator_A.add(Dense(h_A[2], kernel_initializer=glorot_normal(seed=None)))
estimator_A.add(BatchNormalization())
estimator_A.add(Activation('sigmoid'))
estimator_A.add(Dense(y_dim, kernel_initializer=glorot_normal(seed=None)))
estimator_A.add(BatchNormalization())
# estimator_A.add(Activation('sigmoid'))

# Compile model
estimator_A.compile(loss='mean_squared_error', optimizer='adam')

# %%
h5f = h5py.File('TIMIT/Organized/concatenated/mixed'  + data_series + '.hdf5','r')
ftr_shape = h5f['mixed' + data_series].shape
h5f.close()
batch_size = 100
steps_per_epoch = int(ftr_shape[1]/(batch_size))

# %%
tic = time.time()
estimator_A.fit_generator(generator=da(batch_size, ftr_shape[1]),
                          steps_per_epoch=steps_per_epoch,
                          epochs=100,
                          verbose=1)
toc  =time.time()
# Out:
# Epoch 1/100
# [139000  19600  25300 ... 165300 260700 273200]
# 2798/2798 [==============================] - 23s 8ms/step - loss: 0.0141
# Epoch 2/100
# 2798/2798 [==============================] - 23s 8ms/step - loss: 0.0023
# Epoch 3/100
# 2798/2798 [==============================] - 24s 8ms/step - loss: 0.0013
# Epoch 4/100
# 2798/2798 [==============================] - 23s 8ms/step - loss: 9.9922e-04
# Epoch 5/100
# 2798/2798 [==============================] - 23s 8ms/step - loss: 9.9375e-04
# Epoch 6/100
# 2798/2798 [==============================] - 23s 8ms/step - loss: 9.9113e-04
# Epoch 7/100
# 2798/2798 [==============================] - 27s 10ms/step - loss: 9.8751e-04
# Epoch 8/100
# 2798/2798 [==============================] - 29s 10ms/step - loss: 9.8164e-04
# Epoch 9/100
# 2798/2798 [==============================] - 30s 11ms/step - loss: 9.7456e-04
# Epoch 10/100
# 2798/2798 [==============================] - 44s 16ms/step - loss: 9.6804e-04
# Epoch 11/100
# 2798/2798 [==============================] - 56s 20ms/step - loss: 9.6283e-04
# Epoch 12/100
# 2798/2798 [==============================] - 56s 20ms/step - loss: 9.5849e-04
# Epoch 13/100
# 2798/2798 [==============================] - 56s 20ms/step - loss: 9.5442e-04
# Epoch 14/100
# 2798/2798 [==============================] - 55s 20ms/step - loss: 9.5072e-04
# Epoch 15/100
# 2798/2798 [==============================] - 54s 19ms/step - loss: 9.4711e-04
# Epoch 16/100
# 2798/2798 [==============================] - 58s 21ms/step - loss: 9.4352e-04
# Epoch 17/100
# 2798/2798 [==============================] - 57s 20ms/step - loss: 9.4009e-04
# Epoch 18/100
# 2798/2798 [==============================] - 58s 21ms/step - loss: 9.3664e-04
# Epoch 19/100
# 2798/2798 [==============================] - 56s 20ms/step - loss: 9.3336e-04
# Epoch 20/100
# 2798/2798 [==============================] - 58s 21ms/step - loss: 9.3033e-04
# Epoch 21/100
# 2798/2798 [==============================] - 59s 21ms/step - loss: 9.2737e-04
# Epoch 22/100
# 2798/2798 [==============================] - 61s 22ms/step - loss: 9.2449e-04
# Epoch 23/100
# 2798/2798 [==============================] - 67s 24ms/step - loss: 9.2200e-04
# Epoch 24/100
# 2798/2798 [==============================] - 69s 25ms/step - loss: 9.1961e-04
# Epoch 25/100
# 2798/2798 [==============================] - 66s 24ms/step - loss: 9.1719e-04
# Epoch 26/100
# 2798/2798 [==============================] - 64s 23ms/step - loss: 9.1504e-04
# Epoch 27/100
# 2798/2798 [==============================] - 68s 24ms/step - loss: 9.1301e-04
# Epoch 28/100
# 2798/2798 [==============================] - 67s 24ms/step - loss: 9.1097e-04
# Epoch 29/100
# 2798/2798 [==============================] - 68s 24ms/step - loss: 9.0894e-04
# Epoch 30/100
# 2798/2798 [==============================] - 48s 17ms/step - loss: 9.0710e-04
# Epoch 31/100
# 2798/2798 [==============================] - 23s 8ms/step - loss:
100
# 2798/2798 [==============================] - 23s 8ms/step - loss: 8.3535e-04
# Epoch 99/100
# 2798/2798 [==============================] - 23s 8ms/step - loss: 8.3486e-04
# Epoch 100/100
# 2798/2798 [==============================] - 24s 9ms/step - loss: 8.3429e-04

# %%
print('Time= ', toc - tic)
# print("tIME OF K-FOLD=", (toc_fold - tic)/60)
# print("tIME OF FIT=", (toc_fit - tic)/60)
# Out:
# Time=  3098.140062570572

# %%
print((toc -tic)/60)
# Out:
# 51.63566770950953

# %%
estimator_A.model.save('Models/Two_stage/trained_model12.h5')
# Out:
# /home/majid/anaconda3/envs/Myenv/lib/python3.6/site-packages/keras/engine/sequential.py:110: UserWarning: `Sequential.model` is deprecated. `Sequential` is a subclass of `Model`, you can just use your `Sequential` instance directly.
#   warnings.warn('`Sequential.model` is deprecated. '

# %%
estimator_A.model.save_weights('Models/Two_stage/weights12.h5')

# %%
estimator_A = load_model('Models/Two_stage/trained_model12.h5')
# Out:
# WARNING:tensorflow:From /home/majid/anaconda3/envs/Myenv/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/majid/anaconda3/envs/Myenv/lib/python3.6/site-packages/tensorflow/python/keras/utils/losses_utils.py:170: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /home/majid/anaconda3/envs/Myenv/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
test_point_start0 = 0
test_point_stop0 = 7000

# %%
h5f = h5py.File('TIMIT/Organized/concatenated/mixed4.hdf5','r')
test_input = h5f['mixed4'][:, test_point_start0 : test_point_stop0]
h5f.close()

# %%
h5f = h5py.File('TIMIT/Organized/concatenated/clean4.hdf5','r')
test_target = h5f['clean4'][:, test_point_start0 : test_point_stop0]
h5f.close()

# %%
h5f = h5py.File('TIMIT/Organized/concatenated/phase4.hdf5','r')
angle = h5f['phase4'][:,test_point_start0 : test_point_stop0]
h5f.close()

# %%
test_input = sklearn.preprocessing.normalize(test_input.T, norm='l2', axis=1, copy=True, return_norm=False)
test_target = sklearn.preprocessing.normalize(test_target.T, norm='l2', axis=1, copy=True, return_norm=False)

# %%
test_input = test_input.T
test_target = test_target.T

# %%
print(test_input.shape)
print(test_target.shape)
print(angle.shape)
# Out:
# (257, 7000)
# (514, 7000)
# (257, 7000)

# %%
prediction = estimator_A.predict(test_input.T)

# %%
prediction.shape
# Out:
# (7000, 514)

# %%
prediction = np.multiply(test_input.T, prediction[:,257:])

# %%
fft_samples = 257

# %%
s1 = reconstruct(prediction[:,0:fft_samples], angle.T)

# %%
clean_recon = reconstruct(test_target[fft_samples:,:].T, angle.T)

# %%
mixed_recon = reconstruct(test_input[0:fft_samples,:].T, angle.T)

# %%
# 
sd.play(s1*300, 16000)

# %%
sd.play(clean_recon*50, 16000)

# %%
sd.play(mixed_recon*10, 16000)

# %%
st_recon = stoi(s1, clean_recon, 16000, extended=False)

# %%
st_mixed = stoi(mixed_recon, clean_recon, 16000, extended=False)

# %%
print('STOI_recon=', st_recon)
print('STOI_mixed=', st_mixed)
# Out:
# STOI_recon= 0.596826136957907
# STOI_mixed= 0.5490280636185066

# %%
sdr_recon, sir_recon, sar_recon, perm_recon = separation.bss_eval_sources(s1, clean_recon, compute_permutation=True)

# %%
sdr_mixed, sir_mixed, sar_mixed, perm_mixed = separation.bss_eval_sources(mixed_recon, clean_recon, compute_permutation=True)

# %%
print('SDR_recon=', sdr_recon)
print('SDR_mixed=', sdr_mixed)
# Out:
# SDR_recon= [1.76022058]
# SDR_mixed= [1.70953637]

# %%
h5f = h5py.File('TIMIT/Organized/concatenated/mixed4_shuffled.hdf5','r')
a = h5f['mixed4_shuffled'][:,1]
h5f.close()

# %%
for i in range(test_input.shape[1]):
    if np.array_equal(a, test_input[:,i]):
        print(i)
# Out:
# 41603

# %%
type(a)
# Out:
# numpy.ndarray
